# %%
print('hello')
# Out:
# hello

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv

BASE_URL = "https://www.konimex.com"
TARGET_PATH = "/products/pharmaceutical/over-the-counter/"

def scrape_otc_products():
    resp = requests.get(urljoin(BASE_URL, TARGET_PATH), timeout=10)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    products = []
    for h3 in soup.find_all("h3"):
        name = h3.get_text(strip=True)

        # Extract description
        desc = ""
        for sib in h3.next_siblings:
            if isinstance(sib, str) and sib.strip():
                desc = sib.strip()
                break
            if hasattr(sib, "get_text"):
                text = sib.get_text(strip=True)
                if text:
                    desc = text
                    break

        # Extract link
        a = h3.find("a")
        href = a["href"] if a and a.has_attr("href") else None
        link = urljoin(BASE_URL, href) if href else None

        products.append({
            "name": name,
            "description": desc,
            "detail_url": link
        })

    return products

def save_to_csv(data, filename="konimex_otc_products.csv"):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=["name", "description", "detail_url"])
        writer.writeheader()
        writer.writerows(data)

if __name__ == "__main__":
    items = scrape_otc_products()
    save_to_csv(items)
    print(f"✅ Saved {len(items)} items to 'konimex_otc_products.csv'")
# Out:
# ✅ Saved 38 items to 'konimex_otc_products.csv'

# %%
import re
import time
import csv
import requests
from bs4 import BeautifulSoup

# ─── Settings ─────────────────────────────────────────────
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
                  " AppleWebKit/537.36 (KHTML, like Gecko)"
                  " Chrome/113.0.0.0 Safari/537.36"
}
base_listing_url = "https://www.mandjur.co.id/collections/obat-bebas-otc?page={}&grid_list=grid-view"
base_product_url = "https://www.mandjur.co.id/collections/obat-bebas-otc/products/{}"

# ─── 1. Get raw product names from all pages ───────────────────────────────
product_names = []

for page in range(1, 25):
    url = base_listing_url.format(page)
    resp = requests.get(url, headers=headers)
    if resp.status_code != 200:
        print(f"⚠️ Page {page} returned status {resp.status_code}, skipping")
        continue

    soup = BeautifulSoup(resp.text, "html.parser")
    name_tags = soup.select("a.grid-view-item__title, .productitem--title")

    if not name_tags:
        print(f"⚠️ No product titles found on page {page}")

    for tag in name_tags:
        name = tag.get_text(strip=True)
        product_names.append(name)

    time.sleep(0.3)

# ─── 2. Slugify helper ─────────────────────────────────────────────────────
def slugify(name: str) -> str:
    name = name.lower().strip()
    name = re.sub(r"[ _/]+", "-", name)
    name = re.sub(r"[^a-z0-9\-]", "", name)
    name = re.sub(r"-{2,}", "-", name)
    return name

# ─── 3. Visit each product page ────────────────────────────────────────────
rows = []
unique_names = list(dict.fromkeys(product_names))

for name in unique_names:
    slug = slugify(name)
    product_url = base_product_url.format(slug)

    resp = requests.get(product_url, headers=headers)
    if resp.status_code != 200:
        print(f"❌ Failed to load {product_url} (status {resp.status_code})")
        continue

    soup = BeautifulSoup(resp.text, "html.parser")

    title = soup.select_one("h1.product__title, h1.product-single__title")
    price = soup.select_one(".product__price, .product-single__price")
    desc = soup.select_one(".product__description, .rte")

    rows.append({
        "url": product_url,
        "title": title.get_text(strip=True) if title else name,
        "price": price.get_text(strip=True) if price else "",
        "description": desc.get_text(" ", strip=True) if desc else "",
    })

    time.sleep(0.2)

# ─── 4. Save to CSV ────────────────────────────────────────────────────────
with open("products.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["url", "title", "price", "description"])
    writer.writeheader()
    for row in rows:
        writer.writerow(row)

print(f"✅ Done! Scraped {len(rows)} products to products.csv")
# Out:
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/salonpas-pain-relief-patch (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/miconazole-2-cream-10-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alerzin-10-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/degirol-dus-isi-5-strip (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/mirasic-500-mg-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cendo-cenfresh-minidose-06-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/acetylcysteine-200-mg-strip-10-kapsul (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/obh-combi-anak-batuk-plus-flu-jeruk-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/hico-gel-15-g (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alermax-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/sedares-25-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/nalgestan-strip-4-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/l-bio-15-kapsul (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/nellco-special (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/dicom-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/demacolin-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/ultraflu-pe-4-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/komix-obh-dus-isi-30-sachet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/ramolit-424-g-sachet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/siladex-flu-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/trombufit-powder-sachet-12-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/pedialyte-bubble-gum-500-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/molakrim-cream-30-g-krim-pereda-nyeri-otot-dan-sendi (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/opilax-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/opilax-sirup-120-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/erazol-lotion-30-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/erazol-cream-15-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/ostarin-forte-200-mg-5-ml-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/lerzin-5-mg-5-ml-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alloris-10-mg (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alco-drops-15-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/ultraderma-5-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/esemag-6-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/tiriz-10-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/dermatix-wound-care-20-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/dermatix-ultra-gel-5-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alpara-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/bronkris-8-mg-10-tablet-obat-pengencer-dahak (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/promag-tablet-3-blister (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cohistan-expectorant-100-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/dulcolactol-lactulosa-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/pedialyte-original-500-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cendo-lyteers-minidose-06-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/lagesil-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/paranervion-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/plantacid-sirup-100-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/kutilos-10-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/novamag-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/neurosanbe-5000-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/obh-combi-batuk-berdahak-sachet-75-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/ranacid-forte-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/berlosid-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/bufantacid-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/itamol-forte-650-mg-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/mirasic-plus-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/itamol-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/mirasic-forte-650-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/acitral-sirup-120-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/diagit-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/xepazym-strip-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/folic-acid-1000-mcg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/laxadine-emulsi-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cendo-eyefresh-mild-minidose-06-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/interzol-2-cream-5-g (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/mycoral-krim-2 (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/grantusif-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/insto-regular-15-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/anadex-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cendo-asthenof-minidose-06-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/salonpas-cream-hot-30-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/salonpas-cream-30-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/leukoplast-plaster-roll-75-cm-x-45-m (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/bromifar-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/bromifar-plus-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/cetinal-10-mg-10-tablet-kunyah (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/aclonac-emulgel-1-20-g (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/benzolac-25- (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/miravon-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/megatic-gel-20-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/allerin-expectoran-sirup-120-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/prome-sirup-100-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/prome-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/interzinc-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/novaheksin-8-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/bronex-8-mg-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/alleron-4-mg-10-kaplet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/orezinc-sirup-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/wybert-herbal-batuk-plus-60-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/neo-rheumacyl-eucalyptus-100-ml (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/neo-rheumacyl-eucalyptus-cream-25-gr (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/prove-vitamin-d3-1000-iu-10-tablet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/promag-tablet-strip (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/promag-herbal-6-sachet (status 404)
# ❌ Failed to load https://www.mandjur.co.id/collections/obat-bebas-otc/products/antangin-jrg-4-tablet (status 404)
# ✅ Done! Scraped 471 products to products.csv
